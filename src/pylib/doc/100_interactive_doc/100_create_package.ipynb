# %% [markdown]
# This file provides examples on how to use the create_package function.

# %%
# imports and preparations
from pylib import cli
import tempfile
from pathlib import Path

# lets enable autoreload so we can use these scrips for interactive src-debugging.
# %load_ext autoreload
# %autoreload 2

# %%
# print the help of the function
# While this file calls the cli via the cli.run function, all command are also available from
# outside python via the shell. Use help(cli.run) for details.

cli.run(["create-package", "-h"])
# Out:
#
#  Usage: create-package create-package [OPTIONS] DST NAME
#  Create a package that contains all the boilerplate provided by pylib.
#
#  By default, this function injects a copy of pylib into the package. Pass the -imp flag to import instead.
# ╭─ Arguments ─────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ *    dst       PATH  Path where the new package shall be created [required]                                     │
# │ *    name      TEXT  Name of the new package [required]                                                         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─ Options ───────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │         -imp        import from pylib instead of inject.                                                        │
# │ --help  -h          Show this message and exit.                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
# lets create a temp folder and create two packages in there
td = tempfile.TemporaryDirectory(ignore_cleanup_errors=True)

root = Path(td.name)
cli.run(["create-package", str(root), "injected"])
print("\n---\n")
cli.run(["create-package", str(root), "imported", "-imp"])

# %%
# remove the temp dir from above
td.cleanup()
